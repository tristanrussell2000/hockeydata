# %%
import os
from pathlib import Path
from sqlalchemy import create_engine
import pandas as pd

# %%
BASE_DIR = os.path.dirname(Path(os.path.abspath('')))
DATABASE_DIR = os.path.join(BASE_DIR, "db")
DATABASE_FILE_PATH = os.path.join(DATABASE_DIR, "game-data.sqlite")
engine = create_engine(f"sqlite:///{DATABASE_FILE_PATH}")

# %%
unblocked_query = "SELECT shots.*, playerId as GoalieId FROM UnblockedShotGenSupLast25 AS shots LEFT JOIN goalie_saves as gs ON shots.gameId = gs.gameId AND ((shots.isHomeTeam = 1 AND gs.homeRoad = 'H') OR (shots.isHomeTeam = 0 AND gs.homeRoad = 'R')) WHERE gs.gamesStarted = 1"
UnblockedShotGenSup = pd.read_sql_query(unblocked_query, engine)

# %%
UnblockedShotGenSup["gameId"].dtype
# Out:
# 0     2010020007
# 1     2010020017
# 2     2010020027
# 3     2010020036
# 4     2010020048
# 5     2010020056
# 6     2010020086
# 7     2010020100
# 8     2010020112
# 9     2010020128
# 10    2010020142
# 11    2010020155
# 12    2010020159
# 13    2010020168
# 14    2010020179
# 15    2010020211
# 16    2010020227
# 17    2010020248
# 18    2010020270
# 19    2010020289
# Name: gameId, dtype: int64

# %%
goalie_starts = "SELECT playerId, gameId, homeRoad FROM goalie_saves WHERE gamesStarted = 1"
GoalieStarts = pd.read_sql_query(goalie_starts, engine)
games = "SELECT * from games"
Games = pd.read_sql_query(games, engine)

# %%
goalie_save_pct = "SELECT * FROM GoalieSavePct"
GoalieSavePct = pd.read_sql_query(goalie_save_pct, engine)
GoalieSavePct = GoalieSavePct.set_index('goalieId')

# %%
GoalieSavePct.head()
# Out:
#            goals_against  shots_against  diluted_save_pct  raw_save_pct
# goalieId
# 8455710.0            319           3595          0.913166      0.911266
# 8458568.0             19            211          0.918249      0.909953
# 8459140.0            205           2246          0.912200      0.908727
# 8459579.0             11            128          0.919326      0.914062
# 8460535.0            172           2185          0.920879      0.921281

# %%
UnblockedShotGenSup.join(GoalieSavePct, on="GoalieId", how="left").head()
# Out:
#        gameId    season  TeamId           TeamName  isHomeTeam  \
# 0  2010020007  20102011     1.0  New Jersey Devils           1
# 1  2010020017  20102011     1.0  New Jersey Devils           0
# 2  2010020027  20102011     1.0  New Jersey Devils           1
# 3  2010020036  20102011     1.0  New Jersey Devils           0
# 4  2010020048  20102011     1.0  New Jersey Devils           1
#
#    Prev25FenwickForPerHour  Prev25FenwickAgainstPerHour  \
# 0                      NaN                          NaN
# 1                35.733366                    37.250036
# 2                39.099006                    41.675320
# 3                37.648764                    42.137810
# 4                40.258206                    40.970074
#
#    OpponentPrev25FenwickForPerHour  OpponentPrev25FenwickAgainstPerHour  \
# 0                              NaN                                  NaN
# 1                        43.537936                            34.144590
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [gameId, season, TeamId, TeamName, isHomeTeam, Prev25FenwickForPerHour, Prev25FenwickAgainstPerHour, OpponentPrev25FenwickForPerHour, OpponentPrev25FenwickAgainstPerHour, GoalieId]
# Index: []
