# %%
import os
from pathlib import Path
from sqlalchemy import create_engine, text, bindparam
import pandas as pd
import requests
import numpy as np

# %%
BASE_DIR = os.path.dirname(Path(os.path.abspath('')))
DATABASE_DIR = os.path.join(BASE_DIR, "db")
DATABASE_FILE_PATH = os.path.join(DATABASE_DIR, "game-data.sqlite")
engine = create_engine(f"sqlite:///{DATABASE_FILE_PATH}")
NHL_API_BASE_URL = "https://api-web.nhle.com/v1"

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data Import

# %%
unblocked_query = """
WITH GoalieIdJoin AS (
SELECT
shots.gameId,
shots.season,
shots.TeamId,
shots.TeamName,
shots.isHomeTeam,
shots.Prev25FenwickForPerHour,
shots.Prev25FenwickAgainstPerHour,
pp.Prev25ShotsFor5v4PerHour,
pp.Prev25ShotsAgainst4v5PerHour,
spct.Prev25ShootingPercentage,
playerId as GoalieId
FROM UnblockedShotGenSupLast25 AS shots 
LEFT JOIN goalie_saves as gs ON shots.gameId = gs.gameId AND ((shots.isHomeTeam = 1 AND gs.homeRoad = 'H') OR (shots.isHomeTeam = 0 AND gs.homeRoad = 'R')) and gs.gamesStarted = 1 
LEFT JOIN ShotGenSup5v4Last25 as pp ON pp.id = shots.gameId AND pp.teamId = shots.TeamId
LEFT JOIN TeamScoringPercentage as spct ON spct.id = shots.gameId AND spct.teamId = shots.TeamId
)
SELECT GoalieIdJoin.*,
gsave.diluted_save_pct,
games.homeScore > games.visitingScore AS HomeTeamWin
FROM GoalieIdJoin
LEFT JOIN GoalieSavePct as gsave ON gsave.goalieId = GoalieIdJoin.GoalieId
LEFT JOIN games ON games.id = GoalieIdJoin.gameId
"""
UnblockedShotGenSup = pd.read_sql_query(unblocked_query, engine)

# %%
df = UnblockedShotGenSup

# %%
df
# Out:
#            gameId    season  TeamId           TeamName  isHomeTeam  \
# 0      2010020007  20102011       1  New Jersey Devils           1
# 1      2010020017  20102011       1  New Jersey Devils           0
# 2      2010020027  20102011       1  New Jersey Devils           1
# 3      2010020036  20102011       1  New Jersey Devils           0
# 4      2010020048  20102011       1  New Jersey Devils           1
# ...           ...       ...     ...                ...         ...
# 43665  2025020060  20252026      68       Utah Mammoth           1
# 43666  2025020075  20252026      68       Utah Mammoth           1
# 43667  2025020092  20252026      68               None           1
# 43668  2025020107  20252026      68               None           1
# 43669  2025020117  20252026      68               None           0
#
#        Prev25FenwickForPerHour  Prev25FenwickAgainstPerHour  \
# 0                          NaN                          NaN
# 1                    35.731046                    37.251655
# 2                    39.097642                    41.677380
# 3                    37.648014                    42.139441
# 4                    40.259124                    40.970034
# ...                        ...                          ...
# 43665                39.725217                    33.977351
# 43666                40.304810                    35.590220
# 43667                41.427192                    32.957497
# 43668                41.427192                    32.957497
# 43669                41.427192                    32.957497
#
#        Prev25ShotsFor5v4PerHour  Prev25ShotsAgainst4v5PerHour  \
# 0                           NaN                           NaN
# 1                     40.449438                     60.000000
# 2                     79.120879                     56.814921
# 3                     87.022901                     63.258786
# 4                     91.099476                     69.973190
# ...                         ...                           ...
# 43665                 92.988930                     87.804878
# 43666                101.730104                     87.961859
# 43667                110.273327                     87.896104
# 43668                110.273327                     87.896104
# 43669                110.273327                     87.896104
#
#        Prev25ShootingPercentage   GoalieId  diluted_save_pct  HomeTeamWin
# 0                           NaN  8455710.0          0.913166            0
# 1                      0.080000  8455710.0          0.913166            1
# 2                      0.061224  8455710.0          0.913166            0
# 3                      0.055556  8455710.0          0.913166            0
# 4                      0.040000  8455710.0          0.913166            0
# ...                         ...        ...               ...          ...
# 43665                  0.053571  8478872.0          0.913827            1
# 43666                  0.064935  8478872.0          0.913827            1
# 43667                  0.098039  8477970.0          0.916088            0
# 43668                  0.098039        NaN               NaN            0
# 43669                  0.098039        NaN               NaN            0
#
# [43670 rows x 13 columns]

# %%
df.sort_values(by="gameId", ascending=False)
# Out:
#            gameId    season  TeamId             TeamName  isHomeTeam  \
# 43569  2025020126  20252026      20                 None           0
# 43646  2025020126  20252026      52                 None           1
# 43529  2025020125  20252026      15                 None           0
# 43630  2025020125  20252026      29                 None           1
# 43425  2025020124  20252026       1                 None           1
# ...           ...       ...     ...                  ...         ...
# 2556   2010020003  20102011      30       Minnesota Wild           1
# 344    2010020002  20102011       5  Pittsburgh Penguins           1
# 251    2010020002  20102011       4  Philadelphia Flyers           0
# 800    2010020001  20102011      10  Toronto Maple Leafs           1
# 629    2010020001  20102011       8   Montréal Canadiens           0
#
#        Prev25FenwickForPerHour  Prev25FenwickAgainstPerHour  \
# 43569                41.569414                    40.664710
# 43646                26.716608                    38.362516
# 43529                44.999972                    39.981035
# 43630                42.470177                    51.866559
# 43425                46.406479                    39.886922
# ...                        ...                          ...
# 2556                       NaN                          NaN
# 344                        NaN                          NaN
# 251                        NaN                          NaN
# 800                        NaN                          NaN
# 629                        NaN                          NaN
#
#        Prev25ShotsFor5v4PerHour  Prev25ShotsAgainst4v5PerHour  \
# 43569                 86.205102                    111.455108
# 43646                131.220285                    111.428571
# 43529                109.874327                     99.428571
# 43630                 86.971527                    126.266563
# 43425                112.500000                     76.638655
# ...                         ...                           ...
# 2556                        NaN                           NaN
# 344                         NaN                           NaN
# 251                         NaN                           NaN
# 800                         NaN                           NaN
# 629                         NaN                           NaN
#
#        Prev25ShootingPercentage   GoalieId  diluted_save_pct  HomeTeamWin
# 43569                  0.070588        NaN               NaN            0
# 43646                  0.181818        NaN               NaN            0
# 43529                  0.088710        NaN               NaN            0
# 43630                  0.089888        NaN               NaN            0
# 43425                  0.100000        NaN               NaN            0
# ...                         ...        ...               ...          ...
# 2556                        NaN  8473404.0          0.920782            0
# 344                         NaN  8470594.0          0.921912            0
# 251                         NaN  8475683.0          0.924056            0
# 800                         NaN  8462044.0          0.919566            1
# 629                         NaN  8471679.0          0.927053            1
#
# [43670 rows x 13 columns]

# %% [markdown]
# ## Data Processing

# %%
df_home = df[df["isHomeTeam"] == 1].rename(columns={
    "TeamName": "HomeTeamName",
    "TeamId": "HomeTeamId",
    "Prev25FenwickForPerHour": "HomePrev25FenwickForPerHour",
    "Prev25FenwickAgainstPerHour": "HomePrev25FenwickAgainstPerHour",
    "Prev25ShotsFor5v4PerHour": "HomePrev25ShotsFor5v4PerHour",
    "Prev25ShotsAgainst4v5PerHour": "HomePrev25ShotsAgainst4v5PerHour",
    "Prev25ShootingPercentage": "HomePrev25ShootingPercentage",
    "GoalieId": "HomeGoalieId",
    "diluted_save_pct": "HomeDilutedSavePct"
}).drop(["isHomeTeam"], axis=1)
df_away = df[df["isHomeTeam"] == 0].rename(columns={
    "TeamName": "AwayTeamName",
    "TeamId": "AwayTeamId",
    "Prev25FenwickForPerHour": "AwayPrev25FenwickForPerHour",
    "Prev25FenwickAgainstPerHour": "AwayPrev25FenwickAgainstPerHour",
    "Prev25ShotsFor5v4PerHour": "AwayPrev25ShotsFor5v4PerHour",
    "Prev25ShotsAgainst4v5PerHour": "AwayPrev25ShotsAgainst4v5PerHour",
    "Prev25ShootingPercentage": "AwayPrev25ShootingPercentage",
    "GoalieId": "AwayGoalieId",
    "diluted_save_pct": "AwayDilutedSavePct"
}).drop(["season", "isHomeTeam", "HomeTeamWin"], axis=1)

# %%
df_com = pd.merge(left=df_home, right=df_away, how="left", on="gameId")

# %%
df_com.loc[df_com.isnull().any(axis=1)]
# Out:
#            gameId    season  HomeTeamId         HomeTeamName  \
# 0      2010020007  20102011           1    New Jersey Devils
# 41     2010020015  20102011           2   New York Islanders
# 172    2010020002  20102011           5  Pittsburgh Penguins
# 217    2010020012  20102011           6        Boston Bruins
# 271    2010020013  20102011           7       Buffalo Sabres
# ...           ...       ...         ...                  ...
# 38753  2025020087  20252026          54                 None
# 38754  2025020097  20252026          54                 None
# 38755  2025020021  20252026          55       Seattle Kraken
# 38759  2025020092  20252026          68                 None
# 38760  2025020107  20252026          68                 None
#
#        HomePrev25FenwickForPerHour  HomePrev25FenwickAgainstPerHour  \
# 0                              NaN                              NaN
# 41                             NaN                              NaN
# 172                            NaN                              NaN
# 217                            NaN                              NaN
# 271                      44.570909                        37.650589
# ...                            ...                              ...
# 38753                    44.078153                        38.114661
# 38754                    44.078153                        38.114661
# 38755                          NaN                              NaN
# 38759                    41.427192                        32.957497
# 38760                    41.427192                        32.957497
#
#        HomePrev25ShotsFor5v4PerHour  HomePrev25ShotsAgainst4v5PerHour  \
# 0                               NaN                               NaN
# 41                              NaN                               NaN
# 172                             NaN                               NaN
# 217                             NaN                               NaN
# 271                      112.720157                         93.413174
# ...                             ...                               ...
# 38753                    108.531110                         97.864078
# 38754                    108.531110                         97.864078
# 38755                           NaN                               NaN
# 38759                    110.273327                         87.896104
# 38760                    110.273327                         87.896104
#
#        HomePrev25ShootingPercentage  HomeGoalieId  HomeDilutedSavePct  \
# 0                               NaN     8455710.0            0.913166
# 41                              NaN     8468481.0            0.906516
# 172                             NaN     8470594.0            0.921912
# 217                             NaN     8471695.0            0.927981
# 271                        0.043478     8468011.0            0.923425
# ...                             ...           ...                 ...
# 38753                      0.086207     8478499.0            0.914555
# 38754                      0.086207           NaN                 NaN
# 38755                           NaN     8478916.0            0.920209
# 38759                      0.098039     8477970.0            0.916088
# 38760                      0.098039           NaN                 NaN
#
#        HomeTeamWin  AwayTeamId         AwayTeamName  \
# 0                0          25         Dallas Stars
# 41               0          25         Dallas Stars
# 172              0           4  Philadelphia Flyers
# 217              0          27      Phoenix Coyotes
# 271              0           3     New York Rangers
# ...            ...         ...                  ...
# 38753            0          20                 None
# 38754            0          12                 None
# 38755            1          24        Anaheim Ducks
# 38759            0           6                 None
# 38760            0          21                 None
#
#        AwayPrev25FenwickForPerHour  AwayPrev25FenwickAgainstPerHour  \
# 0                              NaN                              NaN
# 41                       36.726480                        35.227308
# 172                            NaN                              NaN
# 217                            NaN                              NaN
# 271                            NaN                              NaN
# ...                            ...                              ...
# 38753                    41.569414                        40.664710
# 38754                    58.980679                        31.056967
# 38755                          NaN                              NaN
# 38759                    45.841060                        42.063199
# 38760                    49.665125                        39.645786
#
#        AwayPrev25ShotsFor5v4PerHour  AwayPrev25ShotsAgainst4v5PerHour  \
# 0                               NaN                               NaN
# 41                        60.000000                         40.449438
# 172                             NaN                               NaN
# 217                             NaN                               NaN
# 271                             NaN                               NaN
# ...                             ...                               ...
# 38753                     86.205102                        111.455108
# 38754                    110.473649                         64.864865
# 38755                           NaN                               NaN
# 38759                    106.521739                         90.789474
# 38760                     92.817680                         84.450402
#
#        AwayPrev25ShootingPercentage  AwayGoalieId  AwayDilutedSavePct
# 0                               NaN     8470140.0            0.923361
# 41                         0.130435     8470140.0            0.923361
# 172                             NaN     8475683.0            0.924056
# 217                             NaN     8468524.0            0.922107
# 271                             NaN     8468685.0            0.926831
# ...                             ...           ...                 ...
# 38753                      0.070588     8481692.0            0.918216
# 38754                      0.130435           NaN                 NaN
# 38755                           NaN     8480843.0            0.916365
# 38759                      0.103774     8476914.0            0.913187
# 38760                      0.094488           NaN                 NaN
#
# [449 rows x 21 columns]

# %%
df_nn = df_com.loc[df_com["HomePrev25FenwickAgainstPerHour"].notna() & df_com["AwayPrev25FenwickForPerHour"].notna()].copy()
df_nn.dropna(inplace=True)

# %%
df_std = df_nn.copy()
cols_to_standardize = ["HomePrev25FenwickForPerHour", "HomePrev25FenwickAgainstPerHour", "HomePrev25ShotsFor5v4PerHour", "HomePrev25ShotsAgainst4v5PerHour", "HomePrev25ShootingPercentage", "HomeDilutedSavePct", "AwayPrev25FenwickForPerHour", "AwayPrev25FenwickAgainstPerHour", "AwayPrev25ShotsFor5v4PerHour", "AwayPrev25ShotsAgainst4v5PerHour", "AwayPrev25ShootingPercentage", "AwayDilutedSavePct"]
df_std[cols_to_standardize] = df_std.groupby('season')[cols_to_standardize].transform(
    lambda x: (x - x.mean()) / x.std()
)

# %%
df_std.dtypes
# Out:
# gameId                                int64
# season                                int64
# HomeTeamId                            int64
# HomeTeamName                         object
# HomePrev25FenwickForPerHour         float64
# HomePrev25FenwickAgainstPerHour     float64
# HomePrev25ShotsFor5v4PerHour        float64
# HomePrev25ShotsAgainst4v5PerHour    float64
# HomePrev25ShootingPercentage        float64
# HomeGoalieId                        float64
# HomeDilutedSavePct                  float64
# HomeTeamWin                           int64
# AwayTeamId                            int64
# AwayTeamName                         object
# AwayPrev25FenwickForPerHour         float64
# AwayPrev25FenwickAgainstPerHour     float64
# AwayPrev25ShotsFor5v4PerHour        float64
# AwayPrev25ShotsAgainst4v5PerHour    float64
# AwayPrev25ShootingPercentage        float64
# AwayGoalieId                        float64
# AwayDilutedSavePct                  float64
# dtype: object

# %%
df_std.iloc[0]
# Out:
# gameId                                       2010020027
# season                                         20102011
# HomeTeamId                                            1
# HomeTeamName                          New Jersey Devils
# HomePrev25FenwickForPerHour                   -0.649706
# HomePrev25FenwickAgainstPerHour                0.118334
# HomePrev25ShotsFor5v4PerHour                  -1.140181
# HomePrev25ShotsAgainst4v5PerHour              -3.099001
# HomePrev25ShootingPercentage                  -1.067386
# HomeGoalieId                                  8455710.0
# HomeDilutedSavePct                            -1.701022
# HomeTeamWin                                           0
# AwayTeamId                                            5
# AwayTeamName                        Pittsburgh Penguins
# AwayPrev25FenwickForPerHour                    1.858938
# AwayPrev25FenwickAgainstPerHour               -0.359108
# AwayPrev25ShotsFor5v4PerHour                  -1.692692
# AwayPrev25ShotsAgainst4v5PerHour               -0.75114
# AwayPrev25ShootingPercentage                  -2.574698
# AwayGoalieId                                  8462161.0
# AwayDilutedSavePct                            -0.755639
# Name: 1, dtype: object

# %%
import pickle

cols = ["HomePrev25FenwickForPerHour",
        "AwayPrev25FenwickForPerHour",
        "HomePrev25FenwickAgainstPerHour",
        "AwayPrev25FenwickAgainstPerHour",
        "HomePrev25ShotsFor5v4PerHour",
        "AwayPrev25ShotsFor5v4PerHour",
        "HomePrev25ShotsAgainst4v5PerHour",
        "AwayPrev25ShotsAgainst4v5PerHour",
        "HomePrev25ShootingPercentage",
        "AwayPrev25ShootingPercentage",
        "HomeDilutedSavePct",
        "AwayDilutedSavePct"]

# Specify the filename of your saved model
filename = '../hockey_pipeline/src/hockey_pipeline/defs/oscar/oscar.pkl'

# Load the model from the file
with open(filename, 'rb') as f:
    loaded_model = pickle.load(f)
    print(df_std[cols].iloc[0].values.reshape(1, -1))
    print(loaded_model.predict(df_std[cols].iloc[0].values.reshape(1, -1)))
# Out:
# [[-0.6497059   1.85893772  0.1183343  -0.35910819 -1.14018086 -1.69269178
#   -3.09900119 -0.7511404  -1.06738604 -2.57469785 -1.70102214 -0.75563947]]
# [1]
# /Users/tristanrussell/Documents/hockeydata/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Logistic Regression Model Fitting

# %%
from sklearn.linear_model import LogisticRegression

# %%
df_std.dtypes
# Out:
# gameId                                int64
# season                                int64
# HomeTeamId                            int64
# HomeTeamName                         object
# HomePrev25FenwickForPerHour         float64
# HomePrev25FenwickAgainstPerHour     float64
# HomePrev25ShotsFor5v4PerHour        float64
# HomePrev25ShotsAgainst4v5PerHour    float64
# HomePrev25ShootingPercentage        float64
# HomeGoalieId                        float64
# HomeDilutedSavePct                  float64
# HomeTeamWin                           int64
# AwayTeamId                            int64
# AwayTeamName                         object
# AwayPrev25FenwickForPerHour         float64
# AwayPrev25FenwickAgainstPerHour     float64
# AwayPrev25ShotsFor5v4PerHour        float64
# AwayPrev25ShotsAgainst4v5PerHour    float64
# AwayPrev25ShootingPercentage        float64
# AwayGoalieId                        float64
# AwayDilutedSavePct                  float64
# dtype: object

# %%
cols = ["HomePrev25FenwickForPerHour",
        "AwayPrev25FenwickForPerHour",
        "HomePrev25FenwickAgainstPerHour", 
        "AwayPrev25FenwickAgainstPerHour",
        "HomePrev25ShotsFor5v4PerHour", 
        "AwayPrev25ShotsFor5v4PerHour",
        "HomePrev25ShotsAgainst4v5PerHour", 
        "AwayPrev25ShotsAgainst4v5PerHour",
        "HomePrev25ShootingPercentage", 
        "AwayPrev25ShootingPercentage",
        "HomeDilutedSavePct", 
        "AwayDilutedSavePct"]
X = df_std[cols].copy()
Y = df_std[["HomeTeamWin"]].copy()

# %%
log_reg = LogisticRegression()
log_reg.fit(X, Y.values.ravel())
# Out:
# LogisticRegression()

# %%
list(zip(cols, log_reg.coef_[0]))
# Out:
# [('HomePrev25FenwickForPerHour', np.float64(0.09164746441369945)),
#  ('AwayPrev25FenwickForPerHour', np.float64(-0.10796864506640294)),
#  ('HomePrev25FenwickAgainstPerHour', np.float64(-0.10799787778252273)),
#  ('AwayPrev25FenwickAgainstPerHour', np.float64(0.06433838113119308)),
#  ('HomePrev25ShotsFor5v4PerHour', np.float64(-0.024317240579072447)),
#  ('AwayPrev25ShotsFor5v4PerHour', np.float64(-0.05764681991454236)),
#  ('HomePrev25ShotsAgainst4v5PerHour', np.float64(-0.01560760493471113)),
#  ('AwayPrev25ShotsAgainst4v5PerHour', np.float64(0.044551229614200445)),
#  ('HomePrev25ShootingPercentage', np.float64(-0.016769085178029705)),
#  ('AwayPrev25ShootingPercentage', np.float64(-0.07270555156864159)),
#  ('HomeDilutedSavePct', np.float64(0.14630670257468534)),
#  ('AwayDilutedSavePct', np.float64(-0.160423860805149))]

# %%
cols_pip = ["HomePrev25FenwickForPerHour",
        "AwayPrev25FenwickForPerHour",
        "HomePrev25FenwickAgainstPerHour", 
        "AwayPrev25FenwickAgainstPerHour"]
X_Pip = df_std[cols_pip].copy()
log_reg.fit(X_Pip, Y.values.ravel())
# Out:
# LogisticRegression()

# %%
list(zip(cols_pip, log_reg.coef_[0]))
# Out:
# [('HomePrev25FenwickForPerHour', np.float64(0.09476284895944306)),
#  ('AwayPrev25FenwickForPerHour', np.float64(-0.12425176160901243)),
#  ('HomePrev25FenwickAgainstPerHour', np.float64(-0.10743302803199677)),
#  ('AwayPrev25FenwickAgainstPerHour', np.float64(0.08086551284958746))]

# %% [markdown]
# ## Logistic Regression Grid Search

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV

# %%
log_reg = LogisticRegression()
scores = cross_val_score(log_reg, X, Y.values.ravel(), cv=5, scoring="neg_brier_score")
print(scores)
# Out:
# [-0.24232449 -0.25129833 -0.24103365 -0.24606143 -0.24752208]

# %%
gs = GridSearchCV(log_reg, {
    'C': [0.01, 0.1, 1, 10, 100],
    'fit_intercept': [True, False],
    'solver': ["liblinear", "newton-cholesky", "newton-cg", "saga"]
}, cv=5)

# %%
gs.fit(X, Y.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100],
#                          'fit_intercept': [True, False],
#                          'solver': ['liblinear', 'newton-cholesky', 'newton-cg',
#                                     'saga']})

# %%
gs.best_score_
# Out:
# np.float64(0.5462771970919461)

# %%
gs.best_estimator_.coef_
# Out:
# array([[ 0.0910069 , -0.10694732, -0.10652245,  0.06400875, -0.02341297,
#         -0.05735022, -0.01624346,  0.04447625, -0.01673595, -0.07160007,
#          0.144533  , -0.15853346]])

# %%
df_com
# Out:
#            gameId    season  HomeTeamId       HomeTeamName  \
# 0      2010020007  20102011           1  New Jersey Devils
# 1      2010020027  20102011           1  New Jersey Devils
# 2      2010020048  20102011           1  New Jersey Devils
# 3      2010020056  20102011           1  New Jersey Devils
# 4      2010020100  20102011           1  New Jersey Devils
# ...           ...       ...         ...                ...
# 38756  2025020037  20252026          55     Seattle Kraken
# 38757  2025020060  20252026          68       Utah Mammoth
# 38758  2025020075  20252026          68       Utah Mammoth
# 38759  2025020092  20252026          68               None
# 38760  2025020107  20252026          68               None
#
#        HomePrev25FenwickForPerHour  HomePrev25FenwickAgainstPerHour  \
# 0                              NaN                              NaN
# 1                        39.097642                        41.677380
# 2                        40.259124                        40.970034
# 3                        41.302035                        40.910259
# 4                        39.890359                        41.584814
# ...                            ...                              ...
# 38756                    51.018365                        55.015194
# 38757                    39.725217                        33.977351
# 38758                    40.304810                        35.590220
# 38759                    41.427192                        32.957497
# 38760                    41.427192                        32.957497
#
#        HomePrev25ShotsFor5v4PerHour  HomePrev25ShotsAgainst4v5PerHour  \
# 0                               NaN                               NaN
# 1                         79.120879                         56.814921
# 2                         91.099476                         69.973190
# 3                        101.160660                         67.648553
# 4                         94.778412                         74.913295
# ...                             ...                               ...
# 38756                     45.000000                         90.000000
# 38757                     92.988930                         87.804878
# 38758                    101.730104                         87.961859
# 38759                    110.273327                         87.896104
# 38760                    110.273327                         87.896104
#
#        HomePrev25ShootingPercentage  HomeGoalieId  HomeDilutedSavePct  \
# 0                               NaN     8455710.0            0.913166
# 1                          0.061224     8455710.0            0.913166
# 2                          0.040000     8455710.0            0.913166
# 3                          0.039062     8455710.0            0.913166
# 4                          0.052632     8460704.0            0.917676
# ...                             ...           ...                 ...
# 38756                      0.100000     8478916.0            0.920209
# 38757                      0.053571     8478872.0            0.913827
# 38758                      0.064935     8478872.0            0.913827
# 38759                      0.098039     8477970.0            0.916088
# 38760                      0.098039           NaN                 NaN
#
#        HomeTeamWin  AwayTeamId          AwayTeamName  \
# 0                0          25          Dallas Stars
# 1                0           5   Pittsburgh Penguins
# 2                0          21    Colorado Avalanche
# 3                0           6         Boston Bruins
# 4                0           7        Buffalo Sabres
# ...            ...         ...                   ...
# 38756            1          54  Vegas Golden Knights
# 38757            1          20        Calgary Flames
# 38758            1          28       San Jose Sharks
# 38759            0           6                  None
# 38760            0          21                  None
#
#        AwayPrev25FenwickForPerHour  AwayPrev25FenwickAgainstPerHour  \
# 0                              NaN                              NaN
# 1                        48.223979                        40.013922
# 2                        42.874015                        42.267633
# 3                        52.916474                        45.152332
# 4                        44.323222                        38.074503
# ...                            ...                              ...
# 38756                    45.633869                        32.853356
# 38757                    41.683309                        40.304264
# 38758                    28.194313                        63.029219
# 38759                    45.841060                        42.063199
# 38760                    49.665125                        39.645786
#
#        AwayPrev25ShotsFor5v4PerHour  AwayPrev25ShotsAgainst4v5PerHour  \
# 0                               NaN                               NaN
# 1                         71.523179                         84.297521
# 2                         62.983425                        110.297872
# 3                        105.017503                        108.724832
# 4                         98.392283                        101.694915
# ...                             ...                               ...
# 38756                     80.000000                         97.297297
# 38757                     85.659164                        109.006211
# 38758                     77.450199                         96.601073
# 38759                    106.521739                         90.789474
# 38760                     92.817680                         84.450402
#
#        AwayPrev25ShootingPercentage  AwayGoalieId  AwayDilutedSavePct
# 0                               NaN     8470140.0            0.923361
# 1                          0.038462     8462161.0            0.916907
# 2                          0.082353     8467950.0            0.919413
# 3                          0.066667     8460703.0            0.927824
# 4                          0.071770     8468011.0            0.923425
# ...                             ...           ...                 ...
# 38756                      0.083333     8478499.0            0.914555
# 38757                      0.084507     8482445.0            0.912521
# 38758                      0.127660     8482137.0            0.916193
# 38759                      0.103774     8476914.0            0.913187
# 38760                      0.094488           NaN                 NaN
#
# [38761 rows x 21 columns]

# %%
with engine.connect() as conn:
    res = conn.execute(text("""
    SELECT triCode FROM teams WHERE id = 52
    """))
    code = res.all()[0][0]

# %%
roster = requests.get(f"{NHL_API_BASE_URL}/roster/{code}/20252026")

# %%
goalie_ids = [goalie["id"] for goalie in roster.json()["goalies"]]
